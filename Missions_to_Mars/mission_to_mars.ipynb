# %% [markdown]
# ## Preparations

# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests
import time

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# # NASA Mars News

# %%
# URL of page to be scraped
news_url = 'https://mars.nasa.gov/news'
browser.visit(news_url)
time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_40104/3125034580.py in <module>
#       1 # URL of page to be scraped
#       2 news_url = 'https://mars.nasa.gov/news'
# ----> 3 browser.visit(news_url)
#       4 time.sleep(3)
#
# ~\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in visit(self, url)
#     312
#     313     def visit(self, url):
# --> 314         self.driver.get(url)
#     315
#     316     def back(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     435         Loads a web page in the current browser session.
#     436         """
# --> 437         self.execute(Command.GET, {'url': url})
#     438
#     439     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00569943+2595139]
# 	Ordinal0 [0x004FC9F1+2148849]
# 	Ordinal0 [0x003F43F0+1065968]
# 	Ordinal0 [0x003E87C2+1017794]
# 	Ordinal0 [0x003E8FF8+1019896]
# 	Ordinal0 [0x003EA892+1026194]
# 	Ordinal0 [0x003E4219+999961]
# 	Ordinal0 [0x003F5860+1071200]
# 	Ordinal0 [0x0044B2D2+1422034]
# 	Ordinal0 [0x0043B806+1357830]
# 	Ordinal0 [0x00416086+1204358]
# 	Ordinal0 [0x00416F96+1208214]
# 	GetHandleVerifier [0x0070B232+1658114]
# 	GetHandleVerifier [0x007C312C+2411516]
# 	GetHandleVerifier [0x005FF261+560433]
# 	GetHandleVerifier [0x005FE366+556598]
# 	Ordinal0 [0x0050286B+2173035]
# 	Ordinal0 [0x005075F8+2192888]
# 	Ordinal0 [0x005076E5+2193125]
# 	Ordinal0 [0x005111FC+2232828]
# 	BaseThreadInitThunk [0x7699FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77157A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77157A4E+238]

# %%
news_html = browser.html
news_soup = bs(news_html, "html.parser")

# %%
news_title_find = news_soup.find('div', class_="content_title")
news_title = news_title_find.text
# news_title
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_40104/1398743738.py in <module>
# ----> 1 news_title_find = news_soup.find('div', class_="content_title")
#       2 news_title = news_title_find.text
#       3 # news_title
#
# NameError: name 'news_soup' is not defined

# %%
news_p_find = news_soup.find('div', class_ = "article_teaser_body")
news_p = news_p_find.text
# news_p

# %%
print(news_title)
print(news_p)

# %% [markdown]
# ## JPL Mars Space Images - Featured Image

# %%
jpl_url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(jpl_url)

jpl_html = browser.html
jpl_soup = bs(jpl_html, "html.parser")
# print(jpl_soup.prettify())

featured_image = jpl_soup.find('a', class_="button fancybox")
featured_image_url = 'https://www.jpl.nasa.gov'+ featured_image['data-fancybox-href']

print(featured_image_url)

# %% [markdown]
# # Mars Weather

# %%
mars_weather_url = ('https://twitter.com/marswxreport?lang=en')
browser.visit(mars_weather_url)
time.sleep(3)

weather_html = browser.html
weather_soup = bs(weather_html, "html.parser")
# print(weather_soup.prettify())

mars_tweets = [weather_soup.find_all('p', class_="TweetTextSize"), weather_soup.find_all('span', class_="css-901oao css-16my406 r-1qd0xha r-ad9z0x r-bcqeeo r
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33388/1859073184.py in <module>
#       1 # HTML object
# ----> 2 html=browser.html
#       3 # Parse HTML
#       4 soup=bs(html,"html.parser")
#       5 # Retrieve image url
#
# NameError: name 'browser' is not defined

# %%
for tweets in mars_tweets:
    mars_tweet = tweets

# %%
for tweet in mars_tweet:
    if 'InSight' in tweet.text:
        mars_weather = tweet.text
        if tweet.a in tweet:
            mars_weather = mars_weather.strip(tweet.a.text)
        break
print(mars_weather)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33388/1869310298.py in <module>
# ----> 1 featured_image_url=jpl_url+image_url
#       2 featured_image_url
#
# NameError: name 'jpl_url' is not defined

# %%
# Scrape Mars weather from twitter
url='https://twitter.com/marswxreport?lang=en'
browser.visit(url)
html=browser.html
soup=bs(html,'html.parser')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4832/3356234666.py in <module>
#       1 # Scrape Mars weather from twitter
#       2 url='https://twitter.com/marswxreport?lang=en'
# ----> 3 browser.visit(url)
#       4 html=browser.html
#       5 soup=bs(html,'html.parser')
#
# NameError: name 'browser' is not defined

# %%
# Retrieve the latest tweet from Mars weather twitter
mars_weather=soup.find_all('p',class_='TweetTextSize TweetTextSize--normal js-tweet-text tweet-text')[0].text
print(mars_weather)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4832/537877060.py in <module>
#       1 # Retrieve the latest tweet from Mars weather twitter
# ----> 2 mars_weather=soup.find_all('p',class_='TweetTextSize TweetTextSize--normal js-tweet-text tweet-text')[0].text
#       3 print(mars_weather)
#
# NameError: name 'soup' is not defined

# %% [markdown]
# ## Mars Fact

# %%
# Scrape Mars facts from https://space-facts.com/mars/
mars_facts_url = 'https://space-facts.com/mars/'
browser.visit(mars_facts_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4832/3068442862.py in <module>
#       1 # Scrape Mars facts from https://space-facts.com/mars/
#       2 url='https://space-facts.com/mars/'
# ----> 3 tables=pd.read_html(url)
#       4 tables
#
# NameError: name 'pd' is not defined

# %%
tables = pd.read_html(mars_facts_url)
mars_table = tables[0]
mars_table.rename(columns={0:'Facts',1:'Value'}, inplace=True)
mars_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4832/1269644799.py in <module>
# ----> 1 mars_fact=tables[0]
#       2 mars_fact=mars_fact.rename(columns={0:"Profile",1:"Value"},errors="raise")
#       3 mars_fact.set_index("Profile",inplace=True)
#       4 mars_fact
#
# NameError: name 'tables' is not defined

# %%
mars_facts = tables[0].to_html()
mars_facts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4832/4171539531.py in <module>
# ----> 1 fact_table=mars_fact.to_html()
#       2 fact_table
#
# NameError: name 'mars_fact' is not defined

# %% [markdown]
# ## Mars Hemispheres

# %%
# Scrape Mars hemisphere title and image
hemisphere_url = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'
browser.visit(hemisphere_url)

hemisphere_html = browser.html
hemisphere_soup = bs(hemisphere_html, "html.parser")
hemispheres = hemisphere_soup.find_all('a', class_="itemLink")
# hemispheres[0].get('href')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4832/1322024599.py in <module>
#       2 usgs_url='https://astrogeology.usgs.gov'
#       3 url='https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'
# ----> 4 browser.visit(url)
#       5 html=browser.html
#       6 soup=bs(html,'html.parser')
#
# NameError: name 'browser' is not defined

# %%
# Extract hemispheres item elements
link_list = []
for hemi in hemispheres:
    if hemi.get('href') not in link_list:
        link_list.append(hemi.get('href'))
links = ['https://astrogeology.usgs.gov' + link for link in link_list]
links
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4832/3954930111.py in <module>
#       1 # Extract hemispheres item elements
# ----> 2 mars_hems=soup.find('div',class_='collapsible results')
#       3 mars_item=mars_hems.find_all('div',class_='item')
#       4 hemisphere_image_urls=[]
#
# NameError: name 'soup' is not defined

# %%
hemisphere_image_urls = []
for link in links:
    url = link
    browser.visit(url)
        
    mars_html = browser.html 
    soup = bs(mars_html, "html.parser")

    title_text = soup.find('h2', class_="title")
    img_url = soup.find('div', class_="downloads")
        
    hemi_dict = {'title': title_text.text, 'img_url': img_url.a.get('href')}
    hemisphere_image_urls.append(hemi_dict)
hemisphere_image_urls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4832/573111299.py in <module>
#       1 # Loop through each hemisphere item
# ----> 2 for item in mars_item:
#       3     # Error handling
#       4     try:
#       5         # Extract title
#
# NameError: name 'mars_item' is not defined
